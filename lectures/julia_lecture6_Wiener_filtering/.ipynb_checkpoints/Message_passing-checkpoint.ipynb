# %% [markdown]
# # Generalized Wiener Filtering

# %% [markdown]
# Here we define a module which defines custum types for FFT and cls

# %%
module FFTandCls
using PyCall, Dierckx
export FFTgrid, MatrixCls, class, sim_xk, radial_power, squash, squash!


##########################################################
# Custom type definitions
##############################################################

# ---- Holds grid, model and planned FFT parameters for the quadratic estimate.
immutable FFTgrid{dm, T}
	period::Float64
	nside::Int64
	deltx::Float64
	deltk::Float64
	nyq::Float64
	x::Array{Array{Float64,dm},1}
	k::Array{Array{Float64,dm},1}
	r::Array{Float64,dm}
	FFT::T  # saved plan for fast fft
end

#---- Holds the cls expanded out to the 2 d spectral matrices.
immutable MatrixCls{dm}
	cϕϕk::Array{Float64,dm}
	cTTk::Array{Float64,dm}
	cTEk::Array{Float64,dm}
	cEEk::Array{Float64,dm}
	cBBk::Array{Float64,dm}
	cTTnoisek::Array{Float64,dm}
	cEEnoisek::Array{Float64,dm}
	cBBnoisek::Array{Float64,dm}
end

##########################################################
# Type constructors
##############################################################

function FFTgrid(dm, period, nside)
	dm_nsides = fill(nside,dm)   # [nside,...,nside] <- dm times
	deltx     = period / nside
	deltk     = 2π / period
	nyq       = 2π / (2deltx)
	x         = [fill(NaN, dm_nsides...) for i = 1:dm]
	k         = [fill(NaN, dm_nsides...) for i = 1:dm]
	r         =  fill(NaN, dm_nsides...)
	tmp       = rand(Complex{Float64},dm_nsides...)
	unnormalized_FFT = plan_fft(tmp; flags = FFTW.PATIENT, timelimit = 10)
	FFT = complex( (deltx / √(2π))^dm ) * unnormalized_FFT
	FFT \ tmp   # <-- initialize fast ifft
	g = FFTgrid{dm, typeof(FFT)}(period, nside, deltx, deltk, nyq, x, k, r, FFT)
	g.x[:], g.k[:] = getgrid(g)
	g.r[:]  =  √(sum([abs2(kdim) for kdim in g.k]))
	return g
end

function MatrixCls{dm,T}(g::FFTgrid{dm,T}, cls; σTTarcmin=0.0, σEEarcmin=0.0,  σBBarcmin=0.0, beamFWHM=0.0)
	cϕϕk = cls_to_cXXk(cls[:ell], cls[:ϕϕ], g.r)
	cTTk = cls_to_cXXk(cls[:ell], cls[:tt], g.r)
	cTEk = cls_to_cXXk(cls[:ell], cls[:te], g.r)
	cEEk = cls_to_cXXk(cls[:ell], cls[:ee], g.r)
	cBBk = cls_to_cXXk(cls[:ell], cls[:bb], g.r)
	cTTnoisek = cNNkgen(g.r; σarcmin=σTTarcmin, beamFWHM=beamFWHM)
	cEEnoisek = cNNkgen(g.r; σarcmin=σEEarcmin, beamFWHM=beamFWHM)
	cBBnoisek = cNNkgen(g.r; σarcmin=σBBarcmin, beamFWHM=beamFWHM)
	MatrixCls{dm}(cϕϕk, cTTk, cTEk, cEEk, cBBk, cTTnoisek, cEEnoisek, cBBnoisek)
end

##########################################################
# Type constructor helpers
##############################################################

function cls_to_cXXk{dm}(ell, cxxls, r::Array{Float64, dm})
	spl = Spline1D(ell, cxxls; k=1, bc="zero", s=0.0)
	return squash(map(spl, r))::Array{Float64, dm}
end

function cNNkgen{dm}(r::Array{Float64,dm}; σarcmin=0.0, beamFWHM=0.0)
	beamSQ = exp(- (beamFWHM ^ 2) * (abs2(r) .^ 2) ./ (8 * log(2)) )
	σrad = σarcmin * (π / 180 / 60) ^ (dm / 2)
	return ones(size(r)) .* σrad .^ 2 ./ beamSQ
end

function getgrid{T}(g::FFTgrid{2,T})
	xco_side, kco_side = getxkside(g)
	kco1, kco2 = meshgrid(kco_side, kco_side)
	xco1, xco2 = meshgrid(xco_side, xco_side)
	kco    = Array{Float64,2}[kco1, kco2]
	xco    = Array{Float64,2}[xco1, xco2]
	return xco, kco
end

function getxkside{dm,T}(g::FFTgrid{dm,T})
	deltx    = g.period / g.nside
	deltk    = 2π / g.period
	xco_side = zeros(g.nside)
	kco_side = zeros(g.nside)
	for j in 0:(g.nside-1)
		xco_side[j+1] = (j < g.nside/2) ? (j*deltx) : (j*deltx - g.period)
		kco_side[j+1] = (j < g.nside/2) ? (j*deltk) : (j*deltk - 2*π*g.nside/g.period)
	end
	xco_side, kco_side
end

function meshgrid(side_x,side_y)
    	nx = length(side_x)
    	ny = length(side_y)
    	xt = repmat(vec(side_x).', ny, 1)
    	yt = repmat(vec(side_y)  , 1 , nx)
    	return xt, yt
end

##########################################################
# Miscellaneous functions
##############################################################
@pyimport classy

function class(;ϕscale = 0.1, ψscale = 0.1, lmax = 6_000, r = 1.0, omega_b = 0.0224567, omega_cdm=0.118489, tau_reio = 0.128312, theta_s = 0.0104098, logA_s_1010 = 3.29056, n_s =  0.968602)
    cosmo = classy.Class()
    cosmo[:struct_cleanup]()
    cosmo[:empty]()
    params = Dict(
        "output"        => "tCl, pCl, lCl",
        "modes"         => "s,t",
        "lensing"       => "yes",
        "l_max_scalars" => lmax + 500,
        "l_max_tensors" => 3_000, #lmax + 500,
        "omega_b"       => omega_b,
        "omega_cdm"     => omega_cdm,
        "tau_reio"      => tau_reio,
        "100*theta_s"   => 100*theta_s,
        "ln10^{10}A_s"  => logA_s_1010,
        "n_s"           => n_s,
        "r"             => r,
        #"k_pivot"       => 0.05,
        #"k_step_trans"  => 0.1, # 0.01 for super high resolution
        #"l_linstep"     => 10,  # 1 for super high resolution
    )
    cosmo[:set](params)
    cosmo[:compute]()
    cls_ln = cosmo[:lensed_cl](lmax)
    cls = cosmo[:raw_cl](lmax)
    rtn = Dict{Symbol, Array{Float64,1}}(
            :ell      => cls["ell"],
            :ln_tt  => cls_ln["tt"] * (10^6 * cosmo[:T_cmb]()) ^ 2,
            :ln_ee  => cls_ln["ee"] * (10^6 * cosmo[:T_cmb]()) ^ 2,
            :ln_bb  => cls_ln["bb"] * (10^6 * cosmo[:T_cmb]()) ^ 2,
            :ln_te  => cls_ln["te"] * (10^6 * cosmo[:T_cmb]()) ^ 2,
            :ln_tϕ  => cls_ln["tp"] * (10^6 * cosmo[:T_cmb]()),
            :tt => cls["tt"] * (10^6 * cosmo[:T_cmb]()) ^ 2,
            :ee => cls["ee"] * (10^6 * cosmo[:T_cmb]()) ^ 2,
            :bb => cls["bb"] * (10^6 * cosmo[:T_cmb]()) ^ 2,
            :te => cls["te"] * (10^6 * cosmo[:T_cmb]()) ^ 2,
            :tϕ => cls["tp"] * (10^6 * cosmo[:T_cmb]()),
            :ϕϕ     => ϕscale.*cls["pp"],
    )
    return rtn
end

function radial_power{dm,T}(fk, smooth::Number, g::FFTgrid{dm,T})
	rtnk = Float64[]
	dk = g.deltk
	kbins = collect((smooth*dk):(smooth*dk):(g.nyq))
	for wavenumber in kbins
		indx = (wavenumber-smooth*dk) .< g.r .<= (wavenumber+smooth*dk)
		push!(rtnk, sum(abs2(fk[indx]).* (dk.^dm)) / sum(indx))
	end
	return kbins, rtnk
end

# -------- Simulate a mean zero Gaussian random field in the pixel domain given a spectral density.
function sim_xk{dm, T}(cXXk::Array{Float64,dm}, g::FFTgrid{dm, T})
	wx, wk = white_wx_wk(g)
	zk = √(cXXk) .* wk
	zx = real(g.FFT \ zk)
	return zx, zk
end

# ----- white noise
function white_wx_wk{dm, T}(g::FFTgrid{dm, T})
	dx  = g.deltx ^ dm
	wx = randn(size(g.r)) ./ √(dx)
	wk = g.FFT * wx
	return wx, wk
end

squash{T<:Number}(x::T)  = isnan(x) ? zero(T) : isfinite(x) ? x : zero(T)
function squash!{dm,T}(x::Array{T,dm}, mask::BitArray{dm}=trues(size(x)))
	@inbounds @simd for i in eachindex(x)
		if !mask[i] || !isfinite(x[i]) || isnan(x[i])
			x[i] = zero(T)
		end
	end
	return x
end
function squash{dm,T}(x::Array{T,dm}, mask::BitArray{dm}=trues(size(x)))
	y = copy(x)
	return squash!(y, mask)
end


end # end Module
# Out:
# WARNING: replacing module FFTandCls
# FFTandCls

# %% [markdown]
# # Message Passing
#
# Here we impliment the message passing algorithm.
#
# ## Load the module and initialize FFT grid and cls

# %%
FFTW.set_num_threads(CPU_CORES)
using FFTandCls

# ----  set the seed
seedstart = rand(UInt64)
srand(seedstart)

# --- set grid geometry and cls
dm     = 2
nside  = nextprod([2,3,5,7], 1024/2)
period =  2*π / 20 # radians, nside * pi / (180*60) gives 1 arcmin pixels
fsky   =  (period)^2 / (4π)
g      = FFTgrid(dm, period, nside)
cls = class();
# Out:
# WARNING: using FFTandCls.squash! in module Main conflicts with an existing identifier.
# WARNING: using FFTandCls.MatrixCls in module Main conflicts with an existing identifier.
# WARNING: using FFTandCls.sim_xk in module Main conflicts with an existing identifier.
# WARNING: using FFTandCls.class in module Main conflicts with an existing identifier.
# WARNING: using FFTandCls.FFTgrid in module Main conflicts with an existing identifier.

# %% [markdown]
# ## Functions for computing the conditional expected value of the Gibbs conditionals

# %%
# ---- get the low pass coefficients in linear order
function get_low_coeffsk(vk, kmask, g)
    return vk[kmask]
end

# ---- convert the low pass coefficients in linear order to matrix form
function embed_low_coeffs(low_coeffsk, kmask, g)
    vk = zeros(Complex{Float64}, size(g.r))
    vk[kmask] = low_coeffsk
    return vk
end

# --- precompute the low rank inverse
function get_lowrankinv(Ntildx, mCls, kmask, g)
    Λ         = get_low_coeffsk(mCls.cTTk ./ (g.deltx ^ 2), kmask, g)
    fft_invÑ  = g.FFT * (1 ./ Ntildx)
    k1        = get_low_coeffsk(g.k[1], kmask, g)
    k2        = get_low_coeffsk(g.k[2], kmask, g)
    n         = length(Λ)
    mat       = Array(Complex{Float64}, n,n)
    for k in 1:n, j in 1:n
        indxcol = findmin(abs2(k1[j] - k1[k] - g.k[1][1,:]))[2]
        indxrow = findmin(abs2(k2[j] - k2[k] - g.k[2][:,1]))[2]
        mat[j,k] = (g.deltk^2 / (2π)) * fft_invÑ[indxrow, indxcol]
    end
    lowrank    = diagm(1./Λ) + mat
    lowrankinv = inv(lowrank)
    return lowrankinv
end

# --- function for computing E(lx| hbarx , hk, dx)
function wf_lx(dx, hbarx, Ntildx, lowrankinv, mCls, kmask, g)
    r1   = (dx - hbarx) ./ Ntildx
    r2   = g.FFT * r1
    r3   = get_low_coeffsk(r2, kmask, g)
    r4   = lowrankinv * r3
    r5   = real(g.FFT \ embed_low_coeffs(r4, kmask, g))
    r6   = r5 ./ Ntildx
    r7   = r1 - r6
    r8   = g.FFT * r7
    r8 .*= mCls.cTTk .* kmask ./ (g.deltx ^ 2)
    lx   =  real(g.FFT \ r8)
    return lx
end


# --- function for computing E(hbarx | lx, hx, dx)
function wf_hbarx(hx, lx, dx, Nbarx, Ntildx)
    hbarx = Array(Float64, size(hx))
    @inbounds @simd for i in eachindex(hbarx)
        hbarx[i] = ((dx[i]-lx[i])/Ntildx[i] + hx[i]/Nbarx[i]) / (1/Nbarx[i] + 1/Ntildx[i])
    end
    return hbarx
end


# --- function for computing E(hk| lx, hbark , dx)
function wf_hk(hbark, nbar_prop_var, mCls, hmask, g)
    hk = Array(Complex{Float64}, size(hbark))
    @inbounds @simd for i in eachindex(hk)
        hk[i] = mCls.cTTk[i] * hbark[i] / (nbar_prop_var * mCls.cTTnoisek[i]  + mCls.cTTk[i])
    end
    return hk .* hmask
end


# --- stopping criterion
function wferror(wftest, dx, Nx, mCls, g)
    b  = squash!(dx ./ Nx)
    Ax = real(g.FFT \ squash!((g.FFT * wftest) ./ (mCls.cTTk/g.deltx^2) ))  + squash!(wftest ./ Nx)
    return norm(Ax - b)/norm(b), norm(Ax - b)
end
# Out:
# wferror (generic function with 1 method)

# %% [markdown]
# ## Now run the algorithm on a simulation

# %% [markdown]
# Set the noise level, the beam and the masked region

# %%
# ---- matrix form of the cls
mCls = MatrixCls(g, cls; σTTarcmin = 15.0/√(fsky))
beamFWHMarcmin  = 1.0
maskx = g.x[1] .>= 0.6*period/2
beamFWHMradians = beamFWHMarcmin * (π / 180 / 60)
mCls.cTTk[:] = mCls.cTTk .* exp(-abs2(beamFWHMradians .* g.r) / 8 / log(2));

# %% [markdown]
# Simulate the tempurature map and the noise

# %%
# ---- simulate t and noise
tx, tk  = sim_xk(mCls.cTTk, g)
nx, nk  = sim_xk(mCls.cTTnoisek, g)
dx      = tx + nx
dx[maskx] = 0.0;

# %% [markdown]
# Use Sherman-Morrison Woodbury ...

# %%
k1max, k2max, k3max, k4max, k5max = 10g.deltk, 14g.deltk, 17g.deltk, 19g.deltk, 21g.deltk
l1mask = (abs(g.k[2]./6) .< k1max) & (abs(g.k[1]) .< k1max)
l2mask = (abs(g.k[2]./6) .< k2max) & (abs(g.k[1]) .< k2max) & !l1mask
l3mask = (abs(g.k[2]./6) .< k3max) & (abs(g.k[1]) .< k3max) & !l1mask & !l2mask
l4mask = (abs(g.k[2]./6) .< k4max) & (abs(g.k[1]) .< k4max) & !l1mask & !l2mask & !l3mask
l5mask = (abs(g.k[2]./6) .< k5max) & (abs(g.k[1]) .< k5max) & !l1mask & !l2mask & !l3mask & !l4mask
hmask  = (abs(g.k[2]./6) .< Inf  ) & (abs(g.k[1]) .< Inf)   & !l1mask & !l2mask & !l3mask & !l4mask & !l5mask
# Out:
# 512x512 BitArray{2}:
#  false  false  false  false  false  …  false  false  false  false  false
#  false  false  false  false  false     false  false  false  false  false
#  false  false  false  false  false     false  false  false  false  false
#  false  false  false  false  false     false  false  false  false  false
#  false  false  false  false  false     false  false  false  false  false
#  false  false  false  false  false  …  false  false  false  false  false
#  false  false  false  false  false     false  false  false  false  false
#  false  false  false  false  false     false  false  false  false  false
#  false  false  false  false  false     false  false  false  false  false
#  false  false  false  false  false     false  false  false  false  false
#  false  false  false  false  false  …  false  false  false  false  false
#  false  false  false  false  false     false  false  false  false  false
#  false  false  false  false  false     false  false  false  false  false
#      ⋮                              ⋱                           ⋮
#  false  false  false  false  false  …  false  false  false  false  false
#  false  false  false  false  false     false  false  false  false  false
#  false  false  false  false  false     false  false  false  false  false
#  false  false  false  false  false     false  false  false  false  false
#  false  false  false  false  false     false  false  false  false  false
#  false  false  false  false  false  …  false  false  false  false  false
#  false  false  false  false  false     false  false  false  false  false
#  false  false  false  false  false     false  false  false  false  false
#  false  false  false  false  false     false  false  false  false  false
#  false  false  false  false  false     false  false  false  false  false
#  false  false  false  false  false  …  false  false  false  false  false
#  false  false  false  false  false     false  false  false  false  false

# %% [markdown]
# This is the number of modes in the low rank models

# %%
sum(l1mask), sum(l2mask), sum(l3mask), sum(l4mask), sum(l5mask)
# Out:
# (2261,2248,2190,1700,1892)

# %% [markdown]
# Now decide how much homogenious varianace to contribute to N̄ and then pre-compute the low rank inverses

# %%
nbar_prop_varA = 0.01
NbarxA  =     nbar_prop_varA * ones(size(g.x[1])) .* mCls.cTTnoisek[1] ./ (g.deltx ^ 2)
NtildxA = (1-nbar_prop_varA) * ones(size(g.x[1])) .* mCls.cTTnoisek[1] ./ (g.deltx ^ 2)
NtildxA[maskx] = Inf

@time lowrankinv1A = get_lowrankinv(NtildxA, mCls, l1mask, g)
@time lowrankinv2A = get_lowrankinv(NtildxA, mCls, l2mask, g)
@time lowrankinv3A = get_lowrankinv(NtildxA, mCls, l3mask, g)
@time lowrankinv4A = get_lowrankinv(NtildxA, mCls, l4mask, g)
@time lowrankinv5A = get_lowrankinv(NtildxA, mCls, l5mask, g);
# Out:
#  49.217440 seconds (51.14 M allocations: 120.031 GB, 23.42% gc time)
#  48.336901 seconds (50.54 M allocations: 118.654 GB, 23.21% gc time)
#  44.663339 seconds (47.96 M allocations: 112.611 GB, 23.27% gc time)
#  26.693662 seconds (28.90 M allocations: 67.861 GB, 23.47% gc time)
#  30.156987 seconds (35.80 M allocations: 84.053 GB, 23.63% gc time)

# %% [markdown]
# Initialize the message passing fields

# %%
wfdk  = (mCls.cTTk ./ (mCls.cTTk + mCls.cTTnoisek)) .* (g.FFT * dx)
l1x   = real(g.FFT \ (l1mask .* wfdk))
l2x   = real(g.FFT \ (l2mask .* wfdk))
l3x   = real(g.FFT \ (l3mask .* wfdk))
l4x   = real(g.FFT \ (l4mask .* wfdk))
l5x   = real(g.FFT \ (l5mask .* wfdk))
hk    = hmask .* wfdk
hbarxA = real(g.FFT \ hk) # + √(NbarxA) .* randn(size(g.r))
#l1x, l2x, l3x, l4x, l5x, hbarx    = zeros(dx), zeros(dx), zeros(dx), zeros(dx), zeros(dx), zeros(dx)
tmp_l5x,  tmp_hk    = zeros(dx),  zeros(dx);

# %% [markdown]
# Now run the iterations

# %%
for counter = 1:100
    l1x    = wf_lx(dx, hbarxA + l2x + l3x + l4x + l5x, NtildxA, lowrankinv1A, mCls, l1mask, g)
    l2x    = wf_lx(dx, hbarxA + l1x + l3x + l4x + l5x, NtildxA, lowrankinv2A, mCls, l2mask, g)
    l3x    = wf_lx(dx, hbarxA + l1x + l2x + l4x + l5x, NtildxA, lowrankinv3A, mCls, l3mask, g)
    l4x    = wf_lx(dx, hbarxA + l1x + l2x + l3x + l5x, NtildxA, lowrankinv4A, mCls, l4mask, g)
    l5x    = wf_lx(dx, hbarxA + l1x + l2x + l3x + l4x, NtildxA, lowrankinv5A, mCls, l5mask, g)
    hbarxA  = wf_hbarx(real(g.FFT \ hk), l1x + l2x + l3x + l4x + l5x, dx, NbarxA, NtildxA)
    hk     = wf_hk(g.FFT * hbarxA, nbar_prop_varA, mCls, hmask, g)
    @show wferror(real(g.FFT \ hk) + l1x + l2x + l3x + l4x + l5x, dx, NbarxA+NtildxA, mCls, g)
    tmp_hk, tmp_l5x = copy(hk), copy(l5x)
end
# Out:
# wferror(real(g.FFT \ hk) + l1x + l2x + l3x + l4x + l5x,dx,NbarxA + NtildxA,mCls,g) = (0.9531649982368542,2.8297386199146723)
# wferror(real(g.FFT \ hk) + l1x + l2x + l3x + l4x + l5x,dx,NbarxA + NtildxA,mCls,g) = (0.7228742858245217,2.1460558116639783)
# wferror(real(g.FFT \ hk) + l1x + l2x + l3x + l4x + l5x,dx,NbarxA + NtildxA,mCls,g) = (0.5679438373191787,1.6861011612653194)
# wferror(real(g.FFT \ hk) + l1x + l2x + l3x + l4x + l5x,dx,NbarxA + NtildxA,mCls,g) = (0.4597251141304393,1.3648234171480984)
# wferror(real(g.FFT \ hk) + l1x + l2x + l3x + l4x + l5x,dx,NbarxA + NtildxA,mCls,g) = (0.38638734631377103,1.1470996082870508)
# wferror(real(g.FFT \ hk) + l1x + l2x + l3x + l4x + l5x,dx,NbarxA + NtildxA,mCls,g) = (0.3291380952519778,0.9771390904434324)
# wferror(real(g.FFT \ hk) + l1x + l2x + l3x + l4x + l5x,dx,NbarxA + NtildxA,mCls,g) = (0.2834895574869626,0.8416185557036556)
# wferror(real(g.FFT \ hk) + l1x + l2x + l3x + l4x + l5x,dx,NbarxA + NtildxA,mCls,g) = (0.24692801955120494,0.7330753380113711)
# wferror(real(g.FFT \ hk) + l1x + l2x + l3x + l4x + l5x,dx,NbarxA + NtildxA,mCls,g) = (0.21764343923571894,0.6461358175295965)
# wferror(real(g.FFT \ hk) + l1x + l2x + l3x + l4x + l5x,dx,NbarxA + NtildxA,mCls,g) = (0.1943542098048885,0.5769951838823483)
# wferror(real(g.FFT \ hk) + l1x + l2x + l3x + l4x + l5x,dx,NbarxA + NtildxA,mCls,g) = (0.17600218471925624,0.5225120311915569)
# wferror(real(g.FFT \ hk) + l1x + l2x + l3x + l4x + l5x,dx,NbarxA + NtildxA,mCls,g) = (0.16126393317174814,0.4787573825513459)
# wferror(real(g.FFT \ hk) + l1x + l2x + l3x + l4x + l5x,dx,NbarxA + NtildxA,mCls,g) = (0.14893302276203604,0.44214960376213835)
# wferror(real(g.FFT \ hk) + l1x + l2x + l3x + l4x + l5x,dx,NbarxA + NtildxA,mCls,g) = (0.13831400922041875,0.4106240727368747)
# wferror(real(g.FFT \ hk) + l1x + l2x + l3x + l4x + l5x,dx,NbarxA + NtildxA,mCls,g) = (0.12901841587339258,0.3830274871113443)
# wferror(real(g.FFT \ hk) + l1x + l2x + l3x + l4x + l5x,dx,NbarxA + NtildxA,mCls,g) = (0.12079494638618352,0.3586138029740855)
# wferror(real(g.FFT \ hk) + l1x + l2x + l3x + l4x + l5x,dx,NbarxA + NtildxA,mCls,g) = (0.11346165600659333,0.33684286610947084)
# wferror(real(g.FFT \ hk) + l1x + l2x + l3x + l4x + l5x,dx,NbarxA + NtildxA,mCls,g) = (0.10687817523111301,0.3172979501313317)
# wferror(real(g.FFT \ hk) + l1x + l2x + l3x + l4x + l5x,dx,NbarxA + NtildxA,mCls,g) = (0.1009324487340138,0.2996463872608802)
# wferror(real(g.FFT \ hk) + l1x + l2x + l3x + l4x + l5x,dx,NbarxA + NtildxA,mCls,g) = (0.09553336311519281,0.2836176817208482)
# wferror(real(g.FFT \ hk) + l1x + l2x + l3x + l4x + l5x,dx,NbarxA + NtildxA,mCls,g) = (0.09060607605276333,0.26898964301007516)
# wferror(real(g.FFT \ hk) + l1x + l2x + l3x + l4x + l5x,dx,NbarxA + NtildxA,mCls,g) = (0.08685251815001789,0.257846149722835)
# wferror(real(g.FFT \ hk) + l1x + l2x + l3x + l4x + l5x,dx,NbarxA + NtildxA,mCls,g) = (0.08685251814975278,0.25784614972204795)
# wferror(real(g.FFT \ hk) + l1x + l2x + l3x + l4x + l5x,dx,NbarxA + NtildxA,mCls,g) = (0.08685251814931223,0.25784614972074005)
# wferror(real(g.FFT \ hk) + l1x + l2x + l3x + l4x + l5x,dx,NbarxA + NtildxA,mCls,g) = (0.08685251814922837,0.2578461497204911)
# wferror(real(g.FFT \ hk) + l1x + l2x + l3x + l4x + l5x,dx,NbarxA + NtildxA,mCls,g) = (0.08685251814829437,0.25784614971771824)
# wferror(real(g.FFT \ hk) + l1x + l2x + l3x + l4x + l5x,dx,NbarxA + NtildxA,mCls,g) = (0.08685251814862287,0.25784614971869346)
# wferror(real(g.FFT \ hk) + l1x + l2x + l3x + l4x + l5x,dx,NbarxA + NtildxA,mCls,g) = (0.08685251814858869,0.257846149718592)
# wferror(real(g.FFT \ hk) + l1x + l2x + l3x + l4x + l5x,dx,NbarxA + NtildxA,mCls,g) = (0.08685251814835433,0.25784614971789627)
# wferror(real(g.FFT \ hk) + l1x + l2x + l3x + l4x + l5x,dx,NbarxA + NtildxA,mCls,g) = (0.08685251814844541,0.25784614971816666)
# wferror(real(g.FFT \ hk) + l1x + l2x + l3x + l4x + l5x,dx,NbarxA + NtildxA,mCls,g) = (0.08685251814826597,0.2578461497176339)
# wferror(real(g.FFT \ hk) + l1x + l2x + l3x + l4x + l5x,dx,NbarxA + NtildxA,mCls,g) = (0.08685251814809286,0.25784614971712)
# wferror(real(g.FFT \ hk) + l1x + l2x + l3x + l4x + l5x,dx,NbarxA + NtildxA,mCls,g) = (0.08685251814809615,0.25784614971712977)
# wferror(real(g.FFT \ hk) + l1x + l2x + l3x + l4x + l5x,dx,NbarxA + NtildxA,mCls,g) = (0.08685251814797854,0.2578461497167806)
# wferror(real(g.FFT \ hk) + l1x + l2x + l3x + l4x + l5x,dx,NbarxA + NtildxA,mCls,g) = (0.08685251814765645,0.25784614971582437)
# wferror(real(g.FFT \ hk) + l1x + l2x + l3x + l4x + l5x,dx,NbarxA + NtildxA,mCls,g) = (0.08685251814788864,0.2578461497165137)
# wferror(real(g.FFT \ hk) + l1x + l2x + l3x + l4x + l5x,dx,NbarxA + NtildxA,mCls,g) = (0.08685251814793503,0.25784614971665143)
# wferror(real(g.FFT \ hk) + l1x + l2x + l3x + l4x + l5x,dx,NbarxA + NtildxA,mCls,g) = (0.08685251814800661,0.2578461497168639)
# wferror(real(g.FFT \ hk) + l1x + l2x + l3x + l4x + l5x,dx,NbarxA + NtildxA,mCls,g) = (0.08685251814821579,0.25784614971748493)
# wferror(real(g.FFT \ hk) + l1x + l2x + l3x + l4x + l5x,dx,NbarxA + NtildxA,mCls,g) = (0.08685251814851712,0.25784614971837955)
# wferror(real(g.FFT \ hk) + l1x + l2x + l3x + l4x + l5x,dx,NbarxA + NtildxA,mCls,g) = (0.08685251814806111,0.25784614971702574)
# wferror(real(g.FFT \ hk) + l1x + l2x + l3x + l4x + l5x,dx,NbarxA + NtildxA,mCls,g) = (0.08685251814786936,0.2578461497164565)
# wferror(real(g.FFT \ hk) + l1x + l2x + l3x + l4x + l5x,dx,NbarxA + NtildxA,mCls,g) = (0.08685251814813134,0.25784614971723424)
# wferror(real(g.FFT \ hk) + l1x + l2x + l3x + l4x + l5x,dx,NbarxA + NtildxA,mCls,g) = (0.08685251814823153,0.25784614971753167)
# wferror(real(g.FFT \ hk) + l1x + l2x + l3x + l4x + l5x,dx,NbarxA + NtildxA,mCls,g) = (0.0868525181476498,0.25784614971580466)
# wferror(real(g.FFT \ hk) + l1x + l2x + l3x + l4x + l5x,dx,NbarxA + NtildxA,mCls,g) = (0.08685251814844136,0.2578461497181546)
# wferror(real(g.FFT \ hk) + l1x + l2x + l3x + l4x + l5x,dx,NbarxA + NtildxA,mCls,g) = (0.08685251814775373,0.2578461497161132)
# wferror(real(g.FFT \ hk) + l1x + l2x + l3x + l4x + l5x,dx,NbarxA + NtildxA,mCls,g) = (0.08685251814822868,0.25784614971752323)
# wferror(real(g.FFT \ hk) + l1x + l2x + l3x + l4x + l5x,dx,NbarxA + NtildxA,mCls,g) = (0.08685251814788647,0.25784614971650727)
# wferror(real(g.FFT \ hk) + l1x + l2x + l3x + l4x + l5x,dx,NbarxA + NtildxA,mCls,g) = (0.08685251814799391,0.25784614971682623)
# wferror(real(g.FFT \ hk) + l1x + l2x + l3x + l4x + l5x,dx,NbarxA + NtildxA,mCls,g) = (0.08685251814805894,0.2578461497170193)
# wferror(real(g.FFT \ hk) + l1x + l2x + l3x + l4x + l5x,dx,NbarxA + NtildxA,mCls,g) = (0.08685251814827293,0.25784614971765457)
# wferror(real(g.FFT \ hk) + l1x + l2x + l3x + l4x + l5x,dx,NbarxA + NtildxA,mCls,g) = (0.08685251814809489,0.257846149717126)
# wferror(real(g.FFT \ hk) + l1x + l2x + l3x + l4x + l5x,dx,NbarxA + NtildxA,mCls,g) = (0.08685251814842256,0.25784614971809877)
# wferror(real(g.FFT \ hk) + l1x + l2x + l3x + l4x + l5x,dx,NbarxA + NtildxA,mCls,g) = (0.08685251814822006,0.25784614971749764)
# wferror(real(g.FFT \ hk) + l1x + l2x + l3x + l4x + l5x,dx,NbarxA + NtildxA,mCls,g) = (0.08685251814809866,0.2578461497171372)
# wferror(real(g.FFT \ hk) + l1x + l2x + l3x + l4x + l5x,dx,NbarxA + NtildxA,mCls,g) = (0.08685251814777559,0.2578461497161781)
# wferror(real(g.FFT \ hk) + l1x + l2x + l3x + l4x + l5x,dx,NbarxA + NtildxA,mCls,g) = (0.08685251814773451,0.25784614971605613)
# wferror(real(g.FFT \ hk) + l1x + l2x + l3x + l4x + l5x,dx,NbarxA + NtildxA,mCls,g) = (0.08685251814849529,0.2578461497183147)
# wferror(real(g.FFT \ hk) + l1x + l2x + l3x + l4x + l5x,dx,NbarxA + NtildxA,mCls,g) = (0.08685251814782173,0.2578461497163151)
# wferror(real(g.FFT \ hk) + l1x + l2x + l3x + l4x + l5x,dx,NbarxA + NtildxA,mCls,g) = (0.08685251814824083,0.25784614971755926)
# wferror(real(g.FFT \ hk) + l1x + l2x + l3x + l4x + l5x,dx,NbarxA + NtildxA,mCls,g) = (0.08685251814817087,0.2578461497173516)
# wferror(real(g.FFT \ hk) + l1x + l2x + l3x + l4x + l5x,dx,NbarxA + NtildxA,mCls,g) = (0.08685251814761803,0.25784614971571035)
# wferror(real(g.FFT \ hk) + l1x + l2x + l3x + l4x + l5x,dx,NbarxA + NtildxA,mCls,g) = (0.08685251814794734,0.25784614971668796)
# wferror(real(g.FFT \ hk) + l1x + l2x + l3x + l4x + l5x,dx,NbarxA + NtildxA,mCls,g) = (0.08685251814868936,0.25784614971889086)
# wferror(real(g.FFT \ hk) + l1x + l2x + l3x + l4x + l5x,dx,NbarxA + NtildxA,mCls,g) = (0.0868525181479718,0.2578461497167606)
# wferror(real(g.FFT \ hk) + l1x + l2x + l3x + l4x + l5x,dx,NbarxA + NtildxA,mCls,g) = (0.08685251814806311,0.2578461497170317)
# wferror(real(g.FFT \ hk) + l1x + l2x + l3x + l4x + l5x,dx,NbarxA + NtildxA,mCls,g) = (0.08685251814831431,0.2578461497177774)
# wferror(real(g.FFT \ hk) + l1x + l2x + l3x + l4x + l5x,dx,NbarxA + NtildxA,mCls,g) = (0.08685251814816673,0.2578461497173393)
# wferror(real(g.FFT \ hk) + l1x + l2x + l3x + l4x + l5x,dx,NbarxA + NtildxA,mCls,g) = (0.08685251814799973,0.2578461497168435)
# wferror(real(g.FFT \ hk) + l1x + l2x + l3x + l4x + l5x,dx,NbarxA + NtildxA,mCls,g) = (0.0868525181479742,0.2578461497167677)
# wferror(real(g.FFT \ hk) + l1x + l2x + l3x + l4x + l5x,dx,NbarxA + NtildxA,mCls,g) = (0.08685251814806397,0.25784614971703423)
# wferror(real(g.FFT \ hk) + l1x + l2x + l3x + l4x + l5x,dx,NbarxA + NtildxA,mCls,g) = (0.0868525181481892,0.257846149717406)
# wferror(real(g.FFT \ hk) + l1x + l2x + l3x + l4x + l5x,dx,NbarxA + NtildxA,mCls,g) = (0.08685251814821068,0.2578461497174698)
# wferror(real(g.FFT \ hk) + l1x + l2x + l3x + l4x + l5x,dx,NbarxA + NtildxA,mCls,g) = (0.0868525181480506,0.25784614971699454)
# wferror(real(g.FFT \ hk) + l1x + l2x + l3x + l4x + l5x,dx,NbarxA + NtildxA,mCls,g) = (0.08685251814777283,0.25784614971616987)
# wferror(real(g.FFT \ hk) + l1x + l2x + l3x + l4x + l5x,dx,NbarxA + NtildxA,mCls,g) = (0.08685251814793292,0.25784614971664516)
# wferror(real(g.FFT \ hk) + l1x + l2x + l3x + l4x + l5x,dx,NbarxA + NtildxA,mCls,g) = (0.08685251814785168,0.25784614971640396)
# wferror(real(g.FFT \ hk) + l1x + l2x + l3x + l4x + l5x,dx,NbarxA + NtildxA,mCls,g) = (0.08685251814815094,0.2578461497172924)
# wferror(real(g.FFT \ hk) + l1x + l2x + l3x + l4x + l5x,dx,NbarxA + NtildxA,mCls,g) = (0.08685251814835065,0.25784614971788533)
# wferror(real(g.FFT \ hk) + l1x + l2x + l3x + l4x + l5x,dx,NbarxA + NtildxA,mCls,g) = (0.08685251814784738,0.2578461497163912)
# wferror(real(g.FFT \ hk) + l1x + l2x + l3x + l4x + l5x,dx,NbarxA + NtildxA,mCls,g) = (0.08685251814779522,0.2578461497162364)
# wferror(real(g.FFT \ hk) + l1x + l2x + l3x + l4x + l5x,dx,NbarxA + NtildxA,mCls,g) = (0.08685251814807927,0.25784614971707964)
# wferror(real(g.FFT \ hk) + l1x + l2x + l3x + l4x + l5x,dx,NbarxA + NtildxA,mCls,g) = (0.08685251814810616,0.25784614971715947)
# wferror(real(g.FFT \ hk) + l1x + l2x + l3x + l4x + l5x,dx,NbarxA + NtildxA,mCls,g) = (0.08685251814791287,0.25784614971658565)
# wferror(real(g.FFT \ hk) + l1x + l2x + l3x + l4x + l5x,dx,NbarxA + NtildxA,mCls,g) = (0.08685251814808181,0.2578461497170872)
# wferror(real(g.FFT \ hk) + l1x + l2x + l3x + l4x + l5x,dx,NbarxA + NtildxA,mCls,g) = (0.08685251814810184,0.25784614971714664)
# wferror(real(g.FFT \ hk) + l1x + l2x + l3x + l4x + l5x,dx,NbarxA + NtildxA,mCls,g) = (0.08685251814802045,0.257846149716905)
# wferror(real(g.FFT \ hk) + l1x + l2x + l3x + l4x + l5x,dx,NbarxA + NtildxA,mCls,g) = (0.08685251814805141,0.25784614971699693)
# wferror(real(g.FFT \ hk) + l1x + l2x + l3x + l4x + l5x,dx,NbarxA + NtildxA,mCls,g) = (0.08685251814819735,0.2578461497174302)
# wferror(real(g.FFT \ hk) + l1x + l2x + l3x + l4x + l5x,dx,NbarxA + NtildxA,mCls,g) = (0.0868525181483166,0.25784614971778425)
# wferror(real(g.FFT \ hk) + l1x + l2x + l3x + l4x + l5x,dx,NbarxA + NtildxA,mCls,g) = (0.08685251814805578,0.2578461497170099)
# wferror(real(g.FFT \ hk) + l1x + l2x + l3x + l4x + l5x,dx,NbarxA + NtildxA,mCls,g) = (0.08685251814804687,0.25784614971698344)
# wferror(real(g.FFT \ hk) + l1x + l2x + l3x + l4x + l5x,dx,NbarxA + NtildxA,mCls,g) = (0.08685251814812014,0.257846149717201)
# wferror(real(g.FFT \ hk) + l1x + l2x + l3x + l4x + l5x,dx,NbarxA + NtildxA,mCls,g) = (0.08685251814833332,0.2578461497178339)
# wferror(real(g.FFT \ hk) + l1x + l2x + l3x + l4x + l5x,dx,NbarxA + NtildxA,mCls,g) = (0.08685251814855256,0.25784614971848474)
# wferror(real(g.FFT \ hk) + l1x + l2x + l3x + l4x + l5x,dx,NbarxA + NtildxA,mCls,g) = (0.08685251814809694,0.2578461497171321)
# wferror(real(g.FFT \ hk) + l1x + l2x + l3x + l4x + l5x,dx,NbarxA + NtildxA,mCls,g) = (0.08685251814833629,0.2578461497178427)
# wferror(real(g.FFT \ hk) + l1x + l2x + l3x + l4x + l5x,dx,NbarxA + NtildxA,mCls,g) = (0.08685251814803079,0.2578461497169357)
# wferror(real(g.FFT \ hk) + l1x + l2x + l3x + l4x + l5x,dx,NbarxA + NtildxA,mCls,g) = (0.08685251814822129,0.25784614971750125)

# %% [markdown]
# Plot the results

# %%
figure(figsize = (11,4))
subplot(1,2,1)
imshow(real(g.FFT \ hk) + l1x + l2x + l3x + l4x + l5x, vmin = -400, vmax = 400); colorbar()
subplot(1,2,2)
imshow(dx, vmin = -400, vmax = 400); colorbar()
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x32ccd5f50>)
# PyObject <matplotlib.colorbar.Colorbar object at 0x320f623d0>

# %% [markdown]
# This compares the low rank signal-to-noise ratio to the noise

# %%
    nby2 = round(Int, nside/4)
    plot(g.r[5:nby2,1],mCls.cTTk[5:nby2,1] ./ (mCls.cTTk[5:nby2,1] +  mCls.cTTnoisek[5:nby2,1]))
    plot([k5max-1,k5max, k5max], [.5, 1.1,.5])
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x3215fac50>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x32351aa50>

# %% [markdown]
# # Pre-Conditioned Conjugate Gradient
